# %%
import pandas as pd

# %%
df = pd.read_csv("final.csv")

# %%
df.head()
# Out:
#    draw_sales  jackpot   pp_sales state_abbr  state_draw_sales  \
# 0  33842134.0    177.0  3144938.0         AR          207040.0
# 1  33842134.0    177.0  3144938.0         AZ          790702.0
# 2  33842134.0    177.0  3144938.0         CA         3292686.0
# 3  33842134.0    177.0  3144938.0         CO          560076.0
# 4  33842134.0    177.0  3144938.0         DC           80140.0
#
#    state_pp_sales date_format  ticket_sales    revenue    year      ...        \
# 0         50023.0  2017-12-02      103520.0   257063.0  2017.0      ...
# 1         59666.0  2017-12-02      395351.0   850368.0  2017.0      ...
# 2             0.0  2017-12-02     1646343.0  3292686.0  2017.0      ...
# 3        126852.0  2017-12-02      280038.0   686928.0  2017.0      ...
# 4          6985.0  2017-12-02       40070.0    87125.0  2017.0      ...
#
#   total_winners  Household Income  Median Age  Per Capita Income  Population  \
# ...

# %%
df['norm_tick_sales'] = df['ticket_sales']/df['Population']

# %%
df.tail()
# Out:
#        draw_sales  jackpot   pp_sales state_abbr  state_draw_sales  \
# 36134  37513118.0    144.0  6303025.0         VA          722125.0
# 36135  37513118.0    144.0  6303025.0         VI           29840.0
# 36136  37513118.0    144.0  6303025.0         VT           78778.0
# 36137  37513118.0    144.0  6303025.0         WA          414727.0
# 36138  37513118.0    144.0  6303025.0         WI          845169.0
#
#        state_pp_sales date_format  ticket_sales   revenue    year  \
# 36134        166211.0  2010-03-06      722125.0  888336.0  2010.0
# 36135         18816.0  2010-03-06       29840.0   48656.0  2010.0
# 36136         25085.0  2010-03-06       78778.0  103863.0  2010.0
# 36137         38536.0  2010-03-06      414727.0  453263.0  2010.0
# 36138         81542.0  2010-03-06      845169.0  926711.0  2010.0
#
#             ...        Household Income  Median Age  Per Capita Income  \
# 36134       ...                 61406.0        37.2            32145.0
# ...

# %%
df['norm_revenue'] = df['revenue']/df['Population']

# %%
df.columns
# Out:
# Index(['draw_sales', 'jackpot', 'pp_sales', 'state_abbr', 'state_draw_sales',
#        'state_pp_sales', 'date_format', 'ticket_sales', 'revenue', 'year',
#        'numbers', 'powerball', '1_PB PB', '1_PB PP', '2_PB PB', '2_PB PP',
#        '3 PB', '3 PP', '3_PB PB', '3_PB PP', '4 PB', '4 PP', '4_PB PB',
#        '4_PB PP', '5 PB', '5 PP', '5_PB PB', 'PB_Only PB', 'PB_Only PP',
#        'pb_winners', 'pp_winners', 'states', 'total_winners',
#        'Household Income', 'Median Age', 'Per Capita Income', 'Population',
#        'Poverty Count', 'Poverty Rate', 'Unemployment Count',
#        'Unemployment Rate', 'unique_id', 'norm_tick_sales', 'norm_revenue'],
#       dtype='object')

# %%
df['norm_draw_sale_by_state']=df['state_draw_sales']/df['Population']

# %%
df['norm_pp_sale_by_state'] = df['state_pp_sales']/df['Population']

# %%
df['%_draw_sales'] = df['state_draw_sales']/df['draw_sales'] * 100

# %%
df.head(47)
# Out:
#     draw_sales  jackpot   pp_sales state_abbr  state_draw_sales  \
# 0   33842134.0    177.0  3144938.0         AR          207040.0
# 1   33842134.0    177.0  3144938.0         AZ          790702.0
# 2   33842134.0    177.0  3144938.0         CA         3292686.0
# 3   33842134.0    177.0  3144938.0         CO          560076.0
# 4   33842134.0    177.0  3144938.0         DC           80140.0
# 5   33842134.0    177.0  3144938.0         DE          166354.0
# 6   33842134.0    177.0  3144938.0         FL         3222110.0
# 7   33842134.0    177.0  3144938.0         GA         1041772.0
# 8   33842134.0    177.0  3144938.0         IA          385304.0
# 9   33842134.0    177.0  3144938.0         ID          221306.0
# 10  33842134.0    177.0  3144938.0         IL         1022564.0
# 11  33842134.0    177.0  3144938.0         IN          741664.0
# 12  33842134.0    177.0  3144938.0         KS          302420.0
# 13  33842134.0    177.0  3144938.0         KY          583426.0
# ...

# %%
df.groupby('date_format')['%_draw_sales'].sum()
# Out:
# date_format
# 2010-03-06     98.726541
# 2010-03-10     98.757542
# 2010-03-13     98.737467
# 2010-03-17     98.608095
# 2010-03-20     98.628322
# 2010-03-24     98.648514
# 2010-03-27     98.656042
# 2010-03-31     98.629152
# 2010-04-03     98.610339
# 2010-04-07     98.682924
# 2010-04-10     98.646665
# 2010-04-14     98.672043
# 2010-04-17     98.733262
# 2010-04-21     98.824956
# 2010-04-24     98.677168
# 2010-04-28     98.690409
# 2010-05-01     98.689401
# 2010-05-05     98.707981
# 2010-05-08     98.688921
# 2010-05-12     98.714608
# 2010-05-15     98.727773
# 2010-05-19     98.730532
# 2010-05-22     98.717473
# 2010-05-26     98.766112
# 2010-05-29     98.758714
# 2010-06-02     98.795639
# 2010-06-05     99.524957
# 2010-06-09     98.660464
# 2010-06-12     98.692150
# 2010-06-16     98.722037
#                  ...
# 2017-08-23    100.000000
# 2017-08-26    100.000000
# 2017-08-30    100.000000
# 2017-09-02    100.000000
# 2017-09-06    340.945582
# ...

# %%
len(df)
# Out:
# 36139

# %%
df.to_csv('final.csv', index=False)
