# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re
import json

# %%
def checkdigit(num):
    if num.isdigit():
        return num
    else:
        return "NA"

# Yellow: yellow header stating $2 tickets, Red: change of ticket price from $1 to $2 warning
# change of ticket price from 1/15/12 - PBSalesbystate12012.htm, table 6
def shiftcheck(table_rows):
    if table_rows[0].find('td', attrs={'bgcolor':'Yellow'}) or table_rows[1].find('td', attrs={'bgcolor':'Red'}):
        return 0
    else:
        return 1

# %%
def scraper(link):
    data = []
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    all_tables = soup.findAll('center')    
    
    # table loop
    for table in all_tables:
        print("table " + str(all_tables.index(table)+1) + " start")
        table_rows = table.table.findAll('tr')        
        shift = shiftcheck(table_rows)
            
        # Deviding table in to entries (date row for reference) to devide columns by date for parsing (entries is just an int)
        entries = len(table_rows[2 - shift].findAll('td', attrs={'colspan':'2'}))
        print("entries: "+ str(entries))

        # looping from right to left: most recent -> past
        for i in range(entries-1,-1,-1):            
            shift = shiftcheck(table_rows)
            
            # jackpot amount
            jackpot_beta = re.findall('\d+', table_rows[1 - shift].findAll('td', attrs={'colspan':'2'})[i].text)
            if len(jackpot_beta) == 1:
                jackpot = jackpot_beta[0]
            else:
                jackpot = 'NA'

            # date
            date = table_rows[2 - shift].findAll('td', attrs={'colspan':'2'})[i].text         
            
            # dividing columns to 2
            col_1, col_2 = i*2, (i*2)+1
            
            # total draw sales & power play sales
            split_sales = table_rows[4 - shift].findAll('td')
            split_sales = [ayy for ayy in split_sales if ayy.text != 'Total\nSales']
            draw_sales = checkdigit(split_sales[col_1].text.replace('*','').replace('$','').replace(',',''))
            pp_sales = checkdigit(split_sales[col_2].text.replace('*','').replace('$','').replace(',',''))
            
            # total tickets sold
            if table.find('tr', attrs={'bgcolor':'Lime'}) == None:
                total_sold = "NA"
                shift += 1
            else:
                total_sold = checkdigit(table_rows[5 - shift].findAll('td', attrs={'colspan':'2'})[i].text.replace(',',''))

            # states sales
            states_data = []
            state_rows = [row for row in table_rows[6 - shift:] if len(row.findAll('td')[0].text) == 2]
            for row in state_rows:
                state_name = row.findAll('td')[0].text
                state_draw_sales = checkdigit(row.findAll('td')[col_1+1].text.replace('$','').replace(',',''))
                state_pp_sales = checkdigit(row.findAll('td')[col_2+1].text.replace('$','').replace(',',''))
                states_data.append({'state':state_name,
                                    'state_draw_sales':state_draw_sales,
                                    'state_pp_sales':state_pp_sales})


            data.append({'date':date,
                         'jackpot':jackpot,
                         'total_sold':total_sold,
                         'draw_sales':draw_sales,
                         'pp_sales':pp_sales,
                         'states_data':states_data})

    print('~-~-~ {} COMPLETE!! ~-~-~'.format(link))
    return data

# %%
home_url = 'http://www.lottoreport.com/'
links = ['PBSalesbystate.htm','PBSalesbystate2016.htm',
'PBSalesbystate22015.htm','PBSalesbystate12015.htm',
'PBSalesbystate22014.htm','PBSalesbystate12014.htm',
'PBSalesbystate22013.htm','PBSalesbystate12013.htm',
'PBSalesbystate22012.htm','PBSalesbystate12012.htm',
'PBSalesbystate22011.htm','PBSalesbystate12011.htm',
'PBSalesbystate22010.htm','PBSalesbystate12010.htm']

total_data = []
# link loop
for link in links:
    print("******************************")
    print("link " + str(links.index(link)+1) + " start")
    link_current = home_url + link
    total_data.append({'link':link, 'data':scraper(link_current)})
# Out:
# ******************************
# link 1 start
# table 1 start
# entries: 9
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# table 7 start
# entries: 9
# table 8 start
# entries: 9
# table 9 start
# entries: 9
# table 10 start
# entries: 9
# table 11 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate.htm COMPLETE!! ~-~-~
# ******************************
# link 2 start
# table 1 start
# entries: 2
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# table 7 start
# entries: 9
# table 8 start
# entries: 9
# table 9 start
# entries: 9
# table 10 start
# entries: 9
# table 11 start
# entries: 9
# table 12 start
# entries: 9
# table 13 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate2016.htm COMPLETE!! ~-~-~
# ******************************
# link 3 start
# table 1 start
# entries: 6
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate22015.htm COMPLETE!! ~-~-~
# ******************************
# link 4 start
# table 1 start
# entries: 9
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate12015.htm COMPLETE!! ~-~-~
# ******************************
# link 5 start
# table 1 start
# entries: 9
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate22014.htm COMPLETE!! ~-~-~
# ******************************
# link 6 start
# table 1 start
# entries: 9
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate12014.htm COMPLETE!! ~-~-~
# ******************************
# link 7 start
# table 1 start
# entries: 3
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate22013.htm COMPLETE!! ~-~-~
# ******************************
# link 8 start
# table 1 start
# entries: 9
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# table 7 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate12013.htm COMPLETE!! ~-~-~
# ******************************
# link 9 start
# table 1 start
# entries: 9
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate22012.htm COMPLETE!! ~-~-~
# ******************************
# link 10 start
# table 1 start
# entries: 9
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate12012.htm COMPLETE!! ~-~-~
# ******************************
# link 11 start
# table 1 start
# entries: 2
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# table 7 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate22011.htm COMPLETE!! ~-~-~
# ******************************
# link 12 start
# table 1 start
# entries: 9
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate12011.htm COMPLETE!! ~-~-~
# ******************************
# link 13 start
# table 1 start
# entries: 9
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# table 5 start
# entries: 9
# table 6 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate22010.htm COMPLETE!! ~-~-~
# ******************************
# link 14 start
# table 1 start
# entries: 9
# table 2 start
# entries: 9
# table 3 start
# entries: 9
# table 4 start
# entries: 9
# ~-~-~ http://www.lottoreport.com/PBSalesbystate12010.htm COMPLETE!! ~-~-~

# %%
json_data = json.dumps(total_data)

# %%
total_data
# Out:
# [{'data': [{'date': '12/06/17',
#     'draw_sales': 'NA',
#     'jackpot': '193',
#     'pp_sales': 'NA',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': 'NA',
#       'state_pp_sales': 'NA'},
#      {'state': 'AZ', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'CA', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'CT', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'DC', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'DE', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'FL', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'GA', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'IA', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'ID', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'IL', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'IN', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'KS', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'KY', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'LA', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'MA', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'MD', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'ME', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'MI', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'MN', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'MO', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'MT', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'NC', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'ND', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'NE', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'NH', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'NJ', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'NM', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'NY', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'OH', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'OK', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'OR', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'PA', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'PR', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'RI', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'SC', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'SD', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'TN', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'TX', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'VA', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'VI', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'VT', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'WA', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'WI', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'WV', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'WY', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'}],
#     'total_sold': 'NA'},
#    {'date': '12/02/17',
#     'draw_sales': '33842134',
#     'jackpot': '177',
#     'pp_sales': '3144938',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '207040',
#       'state_pp_sales': '50023'},
#      {'state': 'AZ', 'state_draw_sales': '790702', 'state_pp_sales': '59666'},
#      {'state': 'CA', 'state_draw_sales': '3292686', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '560076', 'state_pp_sales': '126852'},
#      {'state': 'CT', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'DC', 'state_draw_sales': '80140', 'state_pp_sales': '6985'},
#      {'state': 'DE', 'state_draw_sales': '166354', 'state_pp_sales': '12954'},
#      {'state': 'FL',
#       'state_draw_sales': '3222110',
#       'state_pp_sales': '377607'},
#      {'state': 'GA', 'state_draw_sales': '1041772', 'state_pp_sales': '57311'},
#      {'state': 'IA', 'state_draw_sales': '385304', 'state_pp_sales': '57613'},
#      {'state': 'ID', 'state_draw_sales': '221306', 'state_pp_sales': '24927'},
#      {'state': 'IL', 'state_draw_sales': '1022564', 'state_pp_sales': '81137'},
#      {'state': 'IN', 'state_draw_sales': '741664', 'state_pp_sales': '68947'},
#      {'state': 'KS', 'state_draw_sales': '302420', 'state_pp_sales': '21391'},
#      {'state': 'KY', 'state_draw_sales': '583426', 'state_pp_sales': '40966'},
#      {'state': 'LA', 'state_draw_sales': '680204', 'state_pp_sales': '85442'},
#      {'state': 'MA', 'state_draw_sales': '839336', 'state_pp_sales': '47288'},
#      {'state': 'MD', 'state_draw_sales': '722590', 'state_pp_sales': '47763'},
#      {'state': 'ME', 'state_draw_sales': '149902', 'state_pp_sales': '37515'},
#      {'state': 'MI', 'state_draw_sales': '1028652', 'state_pp_sales': '55478'},
#      {'state': 'MN', 'state_draw_sales': '520530', 'state_pp_sales': '21335'},
#      {'state': 'MO', 'state_draw_sales': '760712', 'state_pp_sales': '30628'},
#      {'state': 'MT', 'state_draw_sales': '84252', 'state_pp_sales': '15728'},
#      {'state': 'NC',
#       'state_draw_sales': '1172230',
#       'state_pp_sales': '160987'},
#      {'state': 'ND', 'state_draw_sales': '77902', 'state_pp_sales': '20328'},
#      {'state': 'NE', 'state_draw_sales': '287150', 'state_pp_sales': '22106'},
#      {'state': 'NH', 'state_draw_sales': '248514', 'state_pp_sales': '18584'},
#      {'state': 'NJ', 'state_draw_sales': '1507958', 'state_pp_sales': '87164'},
#      {'state': 'NM', 'state_draw_sales': '198596', 'state_pp_sales': '27566'},
#      {'state': 'NY',
#       'state_draw_sales': '2709238',
#       'state_pp_sales': '111981'},
#      {'state': 'OH', 'state_draw_sales': '890904', 'state_pp_sales': '97021'},
#      {'state': 'OK', 'state_draw_sales': '311726', 'state_pp_sales': '73047'},
#      {'state': 'OR', 'state_draw_sales': '451908', 'state_pp_sales': '37126'},
#      {'state': 'PA',
#       'state_draw_sales': '1726338',
#       'state_pp_sales': '204973'},
#      {'state': 'PR', 'state_draw_sales': '26', 'state_pp_sales': '2'},
#      {'state': 'RI', 'state_draw_sales': '211512', 'state_pp_sales': '25325'},
#      {'state': 'SC', 'state_draw_sales': '596980', 'state_pp_sales': '135032'},
#      {'state': 'SD', 'state_draw_sales': '100286', 'state_pp_sales': '14120'},
#      {'state': 'TN', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'TX',
#       'state_draw_sales': '2266606',
#       'state_pp_sales': '342095'},
#      {'state': 'VA', 'state_draw_sales': '855138', 'state_pp_sales': '84130'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '64168', 'state_pp_sales': '14454'},
#      {'state': 'WA', 'state_draw_sales': '469596', 'state_pp_sales': '32410'},
#      {'state': 'WI', 'state_draw_sales': '643284', 'state_pp_sales': '53359'},
#      {'state': 'WV', 'state_draw_sales': '261384', 'state_pp_sales': '21930'},
#      {'state': 'WY', 'state_draw_sales': '63486', 'state_pp_sales': '13552'}],
#     'total_sold': '16921067'},
#    {'date': '11/29/17',
#     'draw_sales': '29306014',
#     'jackpot': '163',
#     'pp_sales': '2662866',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '175108',
#       'state_pp_sales': '40701'},
#      {'state': 'AZ', 'state_draw_sales': '710842', 'state_pp_sales': '52286'},
#      {'state': 'CA', 'state_draw_sales': '3024832', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '502646', 'state_pp_sales': '112182'},
#      {'state': 'CT', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'DC', 'state_draw_sales': '70890', 'state_pp_sales': '5899'},
#      {'state': 'DE', 'state_draw_sales': '139866', 'state_pp_sales': '10873'},
#      {'state': 'FL',
#       'state_draw_sales': '2721798',
#       'state_pp_sales': '318733'},
#      {'state': 'GA', 'state_draw_sales': '884588', 'state_pp_sales': '48096'},
#      {'state': 'IA', 'state_draw_sales': '340584', 'state_pp_sales': '49294'},
#      {'state': 'ID', 'state_draw_sales': '207166', 'state_pp_sales': '23207'},
#      {'state': 'IL', 'state_draw_sales': '910814', 'state_pp_sales': '71211'},
#      {'state': 'IN', 'state_draw_sales': '604102', 'state_pp_sales': '55844'},
#      {'state': 'KS', 'state_draw_sales': '262706', 'state_pp_sales': '15196'},
#      {'state': 'KY', 'state_draw_sales': '500200', 'state_pp_sales': '34581'},
#      {'state': 'LA', 'state_draw_sales': '578282', 'state_pp_sales': '72434'},
#      {'state': 'MA', 'state_draw_sales': '718764', 'state_pp_sales': '40651'},
#      {'state': 'MD', 'state_draw_sales': '598172', 'state_pp_sales': '39165'},
#      {'state': 'ME', 'state_draw_sales': '123360', 'state_pp_sales': '30462'},
#      {'state': 'MI', 'state_draw_sales': '879848', 'state_pp_sales': '47098'},
#      {'state': 'MN', 'state_draw_sales': '470432', 'state_pp_sales': '19133'},
#      {'state': 'MO', 'state_draw_sales': '671236', 'state_pp_sales': '27356'},
#      {'state': 'MT', 'state_draw_sales': '78338', 'state_pp_sales': '14392'},
#      {'state': 'NC', 'state_draw_sales': '922854', 'state_pp_sales': '128080'},
#      {'state': 'ND', 'state_draw_sales': '72716', 'state_pp_sales': '18689'},
#      {'state': 'NE', 'state_draw_sales': '260468', 'state_pp_sales': '19423'},
#      {'state': 'NH', 'state_draw_sales': '210316', 'state_pp_sales': '16162'},
#      {'state': 'NJ', 'state_draw_sales': '1324948', 'state_pp_sales': '75283'},
#      {'state': 'NM', 'state_draw_sales': '173188', 'state_pp_sales': '23750'},
#      {'state': 'NY', 'state_draw_sales': '2336616', 'state_pp_sales': '96208'},
#      {'state': 'OH', 'state_draw_sales': '774302', 'state_pp_sales': '80377'},
#      {'state': 'OK', 'state_draw_sales': '266948', 'state_pp_sales': '61633'},
#      {'state': 'OR', 'state_draw_sales': '433736', 'state_pp_sales': '33107'},
#      {'state': 'PA',
#       'state_draw_sales': '1466092',
#       'state_pp_sales': '173028'},
#      {'state': 'PR', 'state_draw_sales': '36', 'state_pp_sales': '5'},
#      {'state': 'RI', 'state_draw_sales': '167760', 'state_pp_sales': '20346'},
#      {'state': 'SC', 'state_draw_sales': '484278', 'state_pp_sales': '107600'},
#      {'state': 'SD', 'state_draw_sales': '90332', 'state_pp_sales': '12157'},
#      {'state': 'TN', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'TX',
#       'state_draw_sales': '1923778',
#       'state_pp_sales': '291739'},
#      {'state': 'VA', 'state_draw_sales': '730672', 'state_pp_sales': '70636'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '54934', 'state_pp_sales': '12386'},
#      {'state': 'WA', 'state_draw_sales': '445382', 'state_pp_sales': '29789'},
#      {'state': 'WI', 'state_draw_sales': '571258', 'state_pp_sales': '47253'},
#      {'state': 'WV', 'state_draw_sales': '224056', 'state_pp_sales': '18460'},
#      {'state': 'WY', 'state_draw_sales': '60694', 'state_pp_sales': '12976'}],
#     'total_sold': '14653007'},
#    {'date': '11/25/17',
#     'draw_sales': '28442720',
#     'jackpot': '149',
#     'pp_sales': '2721992',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '176458',
#       'state_pp_sales': '41992'},
#      {'state': 'AZ', 'state_draw_sales': '689528', 'state_pp_sales': '53051'},
#      {'state': 'CA', 'state_draw_sales': '2792580', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '480664', 'state_pp_sales': '110013'},
#      {'state': 'CT', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'DC', 'state_draw_sales': '60022', 'state_pp_sales': '5663'},
#      {'state': 'DE', 'state_draw_sales': '141940', 'state_pp_sales': '11499'},
#      {'state': 'FL',
#       'state_draw_sales': '2855024',
#       'state_pp_sales': '336210'},
#      {'state': 'GA', 'state_draw_sales': '901044', 'state_pp_sales': '50481'},
#      {'state': 'IA', 'state_draw_sales': '329312', 'state_pp_sales': '49922'},
#      {'state': 'ID', 'state_draw_sales': '208828', 'state_pp_sales': '22758'},
#      {'state': 'IL', 'state_draw_sales': '829168', 'state_pp_sales': '68932'},
#      {'state': 'IN', 'state_draw_sales': '638412', 'state_pp_sales': '60665'},
#      {'state': 'KS', 'state_draw_sales': '254218', 'state_pp_sales': '15472'},
#      {'state': 'KY', 'state_draw_sales': '508872', 'state_pp_sales': '36342'},
#      {'state': 'LA', 'state_draw_sales': '588372', 'state_pp_sales': '74807'},
#      {'state': 'MA', 'state_draw_sales': '688846', 'state_pp_sales': '41120'},
#      {'state': 'MD', 'state_draw_sales': '593674', 'state_pp_sales': '40100'},
#      {'state': 'ME', 'state_draw_sales': '129082', 'state_pp_sales': '32584'},
#      {'state': 'MI', 'state_draw_sales': '827670', 'state_pp_sales': '46753'},
#      {'state': 'MN', 'state_draw_sales': '445400', 'state_pp_sales': '19197'},
#      {'state': 'MO', 'state_draw_sales': '634980', 'state_pp_sales': '27486'},
#      {'state': 'MT', 'state_draw_sales': '73700', 'state_pp_sales': '13713'},
#      {'state': 'NC', 'state_draw_sales': '951916', 'state_pp_sales': '135118'},
#      {'state': 'ND', 'state_draw_sales': '64740', 'state_pp_sales': '16807'},
#      {'state': 'NE', 'state_draw_sales': '244688', 'state_pp_sales': '19370'},
#      {'state': 'NH', 'state_draw_sales': '216498', 'state_pp_sales': '17172'},
#      {'state': 'NJ', 'state_draw_sales': '1163232', 'state_pp_sales': '72381'},
#      {'state': 'NM', 'state_draw_sales': '170326', 'state_pp_sales': '23943'},
#      {'state': 'NY', 'state_draw_sales': '2123816', 'state_pp_sales': '94031'},
#      {'state': 'OH', 'state_draw_sales': '723950', 'state_pp_sales': '81319'},
#      {'state': 'OK', 'state_draw_sales': '269014', 'state_pp_sales': '63745'},
#      {'state': 'OR', 'state_draw_sales': '397396', 'state_pp_sales': '31612'},
#      {'state': 'PA',
#       'state_draw_sales': '1435938',
#       'state_pp_sales': '178030'},
#      {'state': 'PR', 'state_draw_sales': '46', 'state_pp_sales': '10'},
#      {'state': 'RI', 'state_draw_sales': '179212', 'state_pp_sales': '21752'},
#      {'state': 'SC', 'state_draw_sales': '526130', 'state_pp_sales': '117843'},
#      {'state': 'SD', 'state_draw_sales': '85408', 'state_pp_sales': '12360'},
#      {'state': 'TN', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'TX',
#       'state_draw_sales': '1890822',
#       'state_pp_sales': '291379'},
#      {'state': 'VA', 'state_draw_sales': '728312', 'state_pp_sales': '73284'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '58566', 'state_pp_sales': '13146'},
#      {'state': 'WA', 'state_draw_sales': '393710', 'state_pp_sales': '27923'},
#      {'state': 'WI', 'state_draw_sales': '541538', 'state_pp_sales': '47475'},
#      {'state': 'WV', 'state_draw_sales': '226768', 'state_pp_sales': '19184'},
#      {'state': 'WY', 'state_draw_sales': '57548', 'state_pp_sales': '11836'}],
#     'total_sold': '14221360'},
#    {'date': '11/22/17',
#     'draw_sales': '29925352',
#     'jackpot': '134',
#     'pp_sales': '2767370',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '179386',
#       'state_pp_sales': '42525'},
#      {'state': 'AZ', 'state_draw_sales': '732614', 'state_pp_sales': '55825'},
#      {'state': 'CA', 'state_draw_sales': '3068934', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '526436', 'state_pp_sales': '118504'},
#      {'state': 'CT', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'DC', 'state_draw_sales': '72472', 'state_pp_sales': '6652'},
#      {'state': 'DE', 'state_draw_sales': '146270', 'state_pp_sales': '11338'},
#      {'state': 'FL',
#       'state_draw_sales': '2846470',
#       'state_pp_sales': '336493'},
#      {'state': 'GA', 'state_draw_sales': '913038', 'state_pp_sales': '49872'},
#      {'state': 'IA', 'state_draw_sales': '348962', 'state_pp_sales': '51750'},
#      {'state': 'ID', 'state_draw_sales': '212364', 'state_pp_sales': '24157'},
#      {'state': 'IL', 'state_draw_sales': '914744', 'state_pp_sales': '73476'},
#      {'state': 'IN', 'state_draw_sales': '620768', 'state_pp_sales': '58388'},
#      {'state': 'KS', 'state_draw_sales': '268264', 'state_pp_sales': '15751'},
#      {'state': 'KY', 'state_draw_sales': '507358', 'state_pp_sales': '35706'},
#      {'state': 'LA', 'state_draw_sales': '584524', 'state_pp_sales': '74454'},
#      {'state': 'MA', 'state_draw_sales': '738508', 'state_pp_sales': '41722'},
#      {'state': 'MD', 'state_draw_sales': '634520', 'state_pp_sales': '41766'},
#      {'state': 'ME', 'state_draw_sales': '131352', 'state_pp_sales': '32742'},
#      {'state': 'MI', 'state_draw_sales': '884494', 'state_pp_sales': '48377'},
#      {'state': 'MN', 'state_draw_sales': '475108', 'state_pp_sales': '19572'},
#      {'state': 'MO', 'state_draw_sales': '686372', 'state_pp_sales': '28538'},
#      {'state': 'MT', 'state_draw_sales': '83534', 'state_pp_sales': '15526'},
#      {'state': 'NC', 'state_draw_sales': '929424', 'state_pp_sales': '130710'},
#      {'state': 'ND', 'state_draw_sales': '72722', 'state_pp_sales': '19112'},
#      {'state': 'NE', 'state_draw_sales': '263044', 'state_pp_sales': '20300'},
#      {'state': 'NH', 'state_draw_sales': '223108', 'state_pp_sales': '17003'},
#      {'state': 'NJ', 'state_draw_sales': '1343196', 'state_pp_sales': '77583'},
#      {'state': 'NM', 'state_draw_sales': '178916', 'state_pp_sales': '24687'},
#      {'state': 'NY', 'state_draw_sales': '2342430', 'state_pp_sales': '99037'},
#      {'state': 'OH', 'state_draw_sales': '788874', 'state_pp_sales': '83818'},
#      {'state': 'OK', 'state_draw_sales': '266256', 'state_pp_sales': '62475'},
#      {'state': 'OR', 'state_draw_sales': '423210', 'state_pp_sales': '33280'},
#      {'state': 'PA',
#       'state_draw_sales': '1504842',
#       'state_pp_sales': '180337'},
#      {'state': 'PR', 'state_draw_sales': '52', 'state_pp_sales': '11'},
#      {'state': 'RI', 'state_draw_sales': '184074', 'state_pp_sales': '22533'},
#      {'state': 'SC', 'state_draw_sales': '508200', 'state_pp_sales': '112962'},
#      {'state': 'SD', 'state_draw_sales': '93154', 'state_pp_sales': '12984'},
#      {'state': 'TN', 'state_draw_sales': 'NA', 'state_pp_sales': 'NA'},
#      {'state': 'TX',
#       'state_draw_sales': '1907128',
#       'state_pp_sales': '293395'},
#      {'state': 'VA', 'state_draw_sales': '764522', 'state_pp_sales': '75235'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '57092', 'state_pp_sales': '12795'},
#      {'state': 'WA', 'state_draw_sales': '462748', 'state_pp_sales': '32002'},
#      {'state': 'WI', 'state_draw_sales': '579534', 'state_pp_sales': '49259'},
#      {'state': 'WV', 'state_draw_sales': '227056', 'state_pp_sales': '19146'},
#      {'state': 'WY', 'state_draw_sales': '62542', 'state_pp_sales': '13417'}],
#     'total_sold': '14962676'},
#    {'date': '11/18/17',
#     'draw_sales': '29509730',
#     'jackpot': '119',
#     'pp_sales': '2807194',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '182710',
#       'state_pp_sales': '44119'},
#      {'state': 'AZ', 'state_draw_sales': '697858', 'state_pp_sales': '53457'},
#      {'state': 'CA', 'state_draw_sales': '2885328', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '492136', 'state_pp_sales': '113426'},
#      {'state': 'CT', 'state_draw_sales': '496970', 'state_pp_sales': '87242'},
#      {'state': 'DC', 'state_draw_sales': '72546', 'state_pp_sales': '6657'},
#      {'state': 'DE', 'state_draw_sales': '145546', 'state_pp_sales': '11424'},
#      {'state': 'FL',
#       'state_draw_sales': '2863684',
#       'state_pp_sales': '340013'},
#      {'state': 'GA', 'state_draw_sales': '950612', 'state_pp_sales': '51297'},
#      {'state': 'IA', 'state_draw_sales': '350142', 'state_pp_sales': '53210'},
#      {'state': 'ID', 'state_draw_sales': '202890', 'state_pp_sales': '23113'},
#      {'state': 'IL', 'state_draw_sales': '866776', 'state_pp_sales': '70512'},
#      {'state': 'IN', 'state_draw_sales': '645504', 'state_pp_sales': '61172'},
#      {'state': 'KS', 'state_draw_sales': '266630', 'state_pp_sales': '15812'},
#      {'state': 'KY', 'state_draw_sales': '519828', 'state_pp_sales': '37268'},
#      {'state': 'LA', 'state_draw_sales': '622018', 'state_pp_sales': '79052'},
#      {'state': 'MA', 'state_draw_sales': '716684', 'state_pp_sales': '42069'},
#      {'state': 'MD', 'state_draw_sales': '643800', 'state_pp_sales': '43324'},
#      {'state': 'ME', 'state_draw_sales': '137492', 'state_pp_sales': '34682'},
#      {'state': 'MI', 'state_draw_sales': '856744', 'state_pp_sales': '47837'},
#      {'state': 'MN', 'state_draw_sales': '451992', 'state_pp_sales': '19452'},
#      {'state': 'MO', 'state_draw_sales': '658314', 'state_pp_sales': '27760'},
#      {'state': 'MT', 'state_draw_sales': '80098', 'state_pp_sales': '14892'},
#      {'state': 'NC', 'state_draw_sales': '984330', 'state_pp_sales': '139977'},
#      {'state': 'ND', 'state_draw_sales': '67920', 'state_pp_sales': '17973'},
#      {'state': 'NE', 'state_draw_sales': '258396', 'state_pp_sales': '20326'},
#      {'state': 'NH', 'state_draw_sales': '224196', 'state_pp_sales': '17160'},
#      {'state': 'NJ', 'state_draw_sales': '1265464', 'state_pp_sales': '76678'},
#      {'state': 'NM', 'state_draw_sales': '180278', 'state_pp_sales': '25381'},
#      {'state': 'NY', 'state_draw_sales': '2285228', 'state_pp_sales': '98418'},
#      {'state': 'OH', 'state_draw_sales': '774344', 'state_pp_sales': '84960'},
#      {'state': 'OK', 'state_draw_sales': '274562', 'state_pp_sales': '65256'},
#      {'state': 'OR', 'state_draw_sales': '382460', 'state_pp_sales': '31617'},
#      {'state': 'PA',
#       'state_draw_sales': '1463538',
#       'state_pp_sales': '179546'},
#      {'state': 'PR', 'state_draw_sales': '84', 'state_pp_sales': '24'},
#      {'state': 'RI', 'state_draw_sales': '190080', 'state_pp_sales': '22905'},
#      {'state': 'SC', 'state_draw_sales': '545310', 'state_pp_sales': '124856'},
#      {'state': 'SD', 'state_draw_sales': '87684', 'state_pp_sales': '12367'},
#      {'state': 'TN', 'state_draw_sales': '677558', 'state_pp_sales': '110354'},
#      {'state': 'TX',
#       'state_draw_sales': '1941622',
#       'state_pp_sales': '301026'},
#      {'state': 'VA', 'state_draw_sales': '773970', 'state_pp_sales': '76934'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '58600', 'state_pp_sales': '13578'},
#      {'state': 'WA', 'state_draw_sales': '410014', 'state_pp_sales': '29157'},
#      {'state': 'WI', 'state_draw_sales': '563410', 'state_pp_sales': '48308'},
#      {'state': 'WV', 'state_draw_sales': '235874', 'state_pp_sales': '20188'},
#      {'state': 'WY', 'state_draw_sales': '58506', 'state_pp_sales': '12415'}],
#     'total_sold': '14754965'},
#    {'date': '11/15/17',
#     'draw_sales': '26385356',
#     'jackpot': '103',
#     'pp_sales': '2502567',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '158848',
#       'state_pp_sales': '38024'},
#      {'state': 'AZ', 'state_draw_sales': '638384', 'state_pp_sales': '49818'},
#      {'state': 'CA', 'state_draw_sales': '2793120', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '455054', 'state_pp_sales': '105777'},
#      {'state': 'CT', 'state_draw_sales': '446550', 'state_pp_sales': '78311'},
#      {'state': 'DC', 'state_draw_sales': '67950', 'state_pp_sales': '6104'},
#      {'state': 'DE', 'state_draw_sales': '126010', 'state_pp_sales': '10137'},
#      {'state': 'FL',
#       'state_draw_sales': '2433898',
#       'state_pp_sales': '294574'},
#      {'state': 'GA', 'state_draw_sales': '789406', 'state_pp_sales': '45880'},
#      {'state': 'IA', 'state_draw_sales': '317044', 'state_pp_sales': '47855'},
#      {'state': 'ID', 'state_draw_sales': '192420', 'state_pp_sales': '22259'},
#      {'state': 'IL', 'state_draw_sales': '805150', 'state_pp_sales': '66852'},
#      {'state': 'IN', 'state_draw_sales': '550308', 'state_pp_sales': '53188'},
#      {'state': 'KS', 'state_draw_sales': '238704', 'state_pp_sales': '14626'},
#      {'state': 'KY', 'state_draw_sales': '453514', 'state_pp_sales': '32840'},
#      {'state': 'LA', 'state_draw_sales': '539454', 'state_pp_sales': '70515'},
#      {'state': 'MA', 'state_draw_sales': '629044', 'state_pp_sales': '37437'},
#      {'state': 'MD', 'state_draw_sales': '550206', 'state_pp_sales': '37421'},
#      {'state': 'ME', 'state_draw_sales': '118080', 'state_pp_sales': '29873'},
#      {'state': 'MI', 'state_draw_sales': '766516', 'state_pp_sales': '43819'},
#      {'state': 'MN', 'state_draw_sales': '420278', 'state_pp_sales': '18075'},
#      {'state': 'MO', 'state_draw_sales': '602930', 'state_pp_sales': '25773'},
#      {'state': 'MT', 'state_draw_sales': '76800', 'state_pp_sales': '14346'},
#      {'state': 'NC', 'state_draw_sales': '825732', 'state_pp_sales': '119336'},
#      {'state': 'ND', 'state_draw_sales': '65414', 'state_pp_sales': '17572'},
#      {'state': 'NE', 'state_draw_sales': '238722', 'state_pp_sales': '18827'},
#      {'state': 'NH', 'state_draw_sales': '192142', 'state_pp_sales': '15331'},
#      {'state': 'NJ', 'state_draw_sales': '1155626', 'state_pp_sales': '70100'},
#      {'state': 'NM', 'state_draw_sales': '168050', 'state_pp_sales': '23288'},
#      {'state': 'NY', 'state_draw_sales': '2061552', 'state_pp_sales': '90687'},
#      {'state': 'OH', 'state_draw_sales': '690316', 'state_pp_sales': '75180'},
#      {'state': 'OK', 'state_draw_sales': '249500', 'state_pp_sales': '59350'},
#      {'state': 'OR', 'state_draw_sales': '382108', 'state_pp_sales': '29426'},
#      {'state': 'PA',
#       'state_draw_sales': '1289648',
#       'state_pp_sales': '160048'},
#      {'state': 'PR', 'state_draw_sales': '96', 'state_pp_sales': '29'},
#      {'state': 'RI', 'state_draw_sales': '158738', 'state_pp_sales': '19652'},
#      {'state': 'SC', 'state_draw_sales': '459928', 'state_pp_sales': '105396'},
#      {'state': 'SD', 'state_draw_sales': '83508', 'state_pp_sales': '11619'},
#      {'state': 'TN', 'state_draw_sales': '591750', 'state_pp_sales': '96931'},
#      {'state': 'TX',
#       'state_draw_sales': '1695446',
#       'state_pp_sales': '263238'},
#      {'state': 'VA', 'state_draw_sales': '674196', 'state_pp_sales': '67817'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '50948', 'state_pp_sales': '11575'},
#      {'state': 'WA', 'state_draw_sales': '394106', 'state_pp_sales': '28163'},
#      {'state': 'WI', 'state_draw_sales': '518002', 'state_pp_sales': '44893'},
#      {'state': 'WV', 'state_draw_sales': '210830', 'state_pp_sales': '17898'},
#      {'state': 'WY', 'state_draw_sales': '59330', 'state_pp_sales': '12707'}],
#     'total_sold': '13192678'},
#    {'date': '11/11/17',
#     'draw_sales': '26639324',
#     'jackpot': '90',
#     'pp_sales': '2627599',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '168232',
#       'state_pp_sales': '41308'},
#      {'state': 'AZ', 'state_draw_sales': '645956', 'state_pp_sales': '51414'},
#      {'state': 'CA', 'state_draw_sales': '2540426', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '454868', 'state_pp_sales': '107690'},
#      {'state': 'CT', 'state_draw_sales': '452326', 'state_pp_sales': '81677'},
#      {'state': 'DC', 'state_draw_sales': '65090', 'state_pp_sales': '5917'},
#      {'state': 'DE', 'state_draw_sales': '136534', 'state_pp_sales': '11190'},
#      {'state': 'FL',
#       'state_draw_sales': '2635636',
#       'state_pp_sales': '311961'},
#      {'state': 'GA', 'state_draw_sales': '848422', 'state_pp_sales': '48402'},
#      {'state': 'IA', 'state_draw_sales': '332428', 'state_pp_sales': '52214'},
#      {'state': 'ID', 'state_draw_sales': '194268', 'state_pp_sales': '22903'},
#      {'state': 'IL', 'state_draw_sales': '788982', 'state_pp_sales': '66629'},
#      {'state': 'IN', 'state_draw_sales': '605914', 'state_pp_sales': '58615'},
#      {'state': 'KS', 'state_draw_sales': '250100', 'state_pp_sales': '15872'},
#      {'state': 'KY', 'state_draw_sales': '478894', 'state_pp_sales': '34618'},
#      {'state': 'LA', 'state_draw_sales': '575402', 'state_pp_sales': '75157'},
#      {'state': 'MA', 'state_draw_sales': '616946', 'state_pp_sales': '38306'},
#      {'state': 'MD', 'state_draw_sales': '578732', 'state_pp_sales': '39499'},
#      {'state': 'ME', 'state_draw_sales': '131744', 'state_pp_sales': '33746'},
#      {'state': 'MI', 'state_draw_sales': '783122', 'state_pp_sales': '45478'},
#      {'state': 'MN', 'state_draw_sales': '417294', 'state_pp_sales': '19627'},
#      {'state': 'MO', 'state_draw_sales': '590994', 'state_pp_sales': '26509'},
#      {'state': 'MT', 'state_draw_sales': '78144', 'state_pp_sales': '15016'},
#      {'state': 'NC', 'state_draw_sales': '894916', 'state_pp_sales': '128925'},
#      {'state': 'ND', 'state_draw_sales': '62810', 'state_pp_sales': '16966'},
#      {'state': 'NE', 'state_draw_sales': '236004', 'state_pp_sales': '19107'},
#      {'state': 'NH', 'state_draw_sales': '206430', 'state_pp_sales': '16339'},
#      {'state': 'NJ', 'state_draw_sales': '1068246', 'state_pp_sales': '67951'},
#      {'state': 'NM', 'state_draw_sales': '174242', 'state_pp_sales': '25232'},
#      {'state': 'NY', 'state_draw_sales': '1967642', 'state_pp_sales': '89782'},
#      {'state': 'OH', 'state_draw_sales': '705848', 'state_pp_sales': '81154'},
#      {'state': 'OK', 'state_draw_sales': '271796', 'state_pp_sales': '66245'},
#      {'state': 'OR', 'state_draw_sales': '341302', 'state_pp_sales': '28971'},
#      {'state': 'PA',
#       'state_draw_sales': '1278188',
#       'state_pp_sales': '163816'},
#      {'state': 'PR', 'state_draw_sales': '102', 'state_pp_sales': '31'},
#      {'state': 'RI', 'state_draw_sales': '176090', 'state_pp_sales': '21777'},
#      {'state': 'SC', 'state_draw_sales': '497264', 'state_pp_sales': '113321'},
#      {'state': 'SD', 'state_draw_sales': '82578', 'state_pp_sales': '11746'},
#      {'state': 'TN', 'state_draw_sales': '648232', 'state_pp_sales': '107995'},
#      {'state': 'TX',
#       'state_draw_sales': '1742860',
#       'state_pp_sales': '275067'},
#      {'state': 'VA', 'state_draw_sales': '701020', 'state_pp_sales': '71357'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '54076', 'state_pp_sales': '12739'},
#      {'state': 'WA', 'state_draw_sales': '54076', 'state_pp_sales': '12739'},
#      {'state': 'WI', 'state_draw_sales': '364642', 'state_pp_sales': '27269'},
#      {'state': 'WV', 'state_draw_sales': '514070', 'state_pp_sales': '45842'},
#      {'state': 'WY', 'state_draw_sales': '223184', 'state_pp_sales': '19795'}],
#     'total_sold': '13319662'},
#    {'date': '11/08/17',
#     'draw_sales': '23435234',
#     'jackpot': '75',
#     'pp_sales': '2337920',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '147466',
#       'state_pp_sales': '36075'},
#      {'state': 'AZ', 'state_draw_sales': '577336', 'state_pp_sales': '47242'},
#      {'state': 'CA', 'state_draw_sales': '2310408', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '392628', 'state_pp_sales': '93601'},
#      {'state': 'CT', 'state_draw_sales': '403646', 'state_pp_sales': '73232'},
#      {'state': 'DC', 'state_draw_sales': '62564', 'state_pp_sales': '5899'},
#      {'state': 'DE', 'state_draw_sales': '118140', 'state_pp_sales': '9809'},
#      {'state': 'FL',
#       'state_draw_sales': '2210366',
#       'state_pp_sales': '267811'},
#      {'state': 'GA', 'state_draw_sales': '717966', 'state_pp_sales': '43453'},
#      {'state': 'IA', 'state_draw_sales': '300038', 'state_pp_sales': '46881'},
#      {'state': 'ID', 'state_draw_sales': '178768', 'state_pp_sales': '21131'},
#      {'state': 'IL', 'state_draw_sales': '717064', 'state_pp_sales': '62692'},
#      {'state': 'IN', 'state_draw_sales': '502276', 'state_pp_sales': '50818'},
#      {'state': 'KS', 'state_draw_sales': '220046', 'state_pp_sales': '14061'},
#      {'state': 'KY', 'state_draw_sales': '422408', 'state_pp_sales': '31411'},
#      {'state': 'LA', 'state_draw_sales': '505180', 'state_pp_sales': '68141'},
#      {'state': 'MA', 'state_draw_sales': '549316', 'state_pp_sales': '35561'},
#      {'state': 'MD', 'state_draw_sales': '504874', 'state_pp_sales': '35950'},
#      {'state': 'ME', 'state_draw_sales': '113162', 'state_pp_sales': '28963'},
#      {'state': 'MI', 'state_draw_sales': '689066', 'state_pp_sales': '42005'},
#      {'state': 'MN', 'state_draw_sales': '383240', 'state_pp_sales': '18060'},
#      {'state': 'MO', 'state_draw_sales': '530482', 'state_pp_sales': '24046'},
#      {'state': 'MT', 'state_draw_sales': '73288', 'state_pp_sales': '14199'},
#      {'state': 'NC', 'state_draw_sales': '762428', 'state_pp_sales': '113291'},
#      {'state': 'ND', 'state_draw_sales': '60034', 'state_pp_sales': '16565'},
#      {'state': 'NE', 'state_draw_sales': '217336', 'state_pp_sales': '17759'},
#      {'state': 'NH', 'state_draw_sales': '176832', 'state_pp_sales': '14476'},
#      {'state': 'NJ', 'state_draw_sales': '978656', 'state_pp_sales': '62945'},
#      {'state': 'NM', 'state_draw_sales': '154922', 'state_pp_sales': '22154'},
#      {'state': 'NY', 'state_draw_sales': '1767220', 'state_pp_sales': '83990'},
#      {'state': 'OH', 'state_draw_sales': '626794', 'state_pp_sales': '72917'},
#      {'state': 'OK', 'state_draw_sales': '238346', 'state_pp_sales': '58354'},
#      {'state': 'OR', 'state_draw_sales': '310772', 'state_pp_sales': '26868'},
#      {'state': 'PA',
#       'state_draw_sales': '1114676',
#       'state_pp_sales': '145882'},
#      {'state': 'PR', 'state_draw_sales': '114', 'state_pp_sales': '35'},
#      {'state': 'RI', 'state_draw_sales': '150768', 'state_pp_sales': '19287'},
#      {'state': 'SC', 'state_draw_sales': '426886', 'state_pp_sales': '97829'},
#      {'state': 'SD', 'state_draw_sales': '77910', 'state_pp_sales': '11432'},
#      {'state': 'TN', 'state_draw_sales': '555648', 'state_pp_sales': '93804'},
#      {'state': 'TX',
#       'state_draw_sales': '1461942',
#       'state_pp_sales': '235873'},
#      {'state': 'VA', 'state_draw_sales': '610790', 'state_pp_sales': '63830'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '47564', 'state_pp_sales': '11026'},
#      {'state': 'WA', 'state_draw_sales': '337850', 'state_pp_sales': '25591'},
#      {'state': 'WI', 'state_draw_sales': '471122', 'state_pp_sales': '42650'},
#      {'state': 'WV', 'state_draw_sales': '200556', 'state_pp_sales': '18188'},
#      {'state': 'WY', 'state_draw_sales': '56340', 'state_pp_sales': '12133'}],
#     'total_sold': '11717617'},
#    {'date': '11/04/17',
#     'draw_sales': '25735618',
#     'jackpot': '64',
#     'pp_sales': '2584601',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '166670',
#       'state_pp_sales': '41709'},
#      {'state': 'AZ', 'state_draw_sales': '606624', 'state_pp_sales': '49378'},
#      {'state': 'CA', 'state_draw_sales': '2327594', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '421270', 'state_pp_sales': '101835'},
#      {'state': 'CT', 'state_draw_sales': '439438', 'state_pp_sales': '80546'},
#      {'state': 'DC', 'state_draw_sales': '68180', 'state_pp_sales': '6396'},
#      {'state': 'DE', 'state_draw_sales': '135758', 'state_pp_sales': '11456'},
#      {'state': 'FL',
#       'state_draw_sales': '2525352',
#       'state_pp_sales': '300851'},
#      {'state': 'GA', 'state_draw_sales': '802912', 'state_pp_sales': '46976'},
#      {'state': 'IA', 'state_draw_sales': '321096', 'state_pp_sales': '50472'},
#      {'state': 'ID', 'state_draw_sales': '187238', 'state_pp_sales': '22039'},
#      {'state': 'IL', 'state_draw_sales': '754034', 'state_pp_sales': '65478'},
#      {'state': 'IN', 'state_draw_sales': '596650', 'state_pp_sales': '59118'},
#      {'state': 'KS', 'state_draw_sales': '290644', 'state_pp_sales': '15090'},
#      {'state': 'KY', 'state_draw_sales': '471290', 'state_pp_sales': '34642'},
#      {'state': 'LA', 'state_draw_sales': '567300', 'state_pp_sales': '75138'},
#      {'state': 'MA', 'state_draw_sales': '598970', 'state_pp_sales': '38313'},
#      {'state': 'MD', 'state_draw_sales': '579984', 'state_pp_sales': '41200'},
#      {'state': 'ME', 'state_draw_sales': '129256', 'state_pp_sales': '33280'},
#      {'state': 'MI', 'state_draw_sales': '753064', 'state_pp_sales': '44629'},
#      {'state': 'MN', 'state_draw_sales': '398504', 'state_pp_sales': '19132'},
#      {'state': 'MO', 'state_draw_sales': '573654', 'state_pp_sales': '25722'},
#      {'state': 'MT', 'state_draw_sales': '73448', 'state_pp_sales': '14381'},
#      {'state': 'NC', 'state_draw_sales': '888916', 'state_pp_sales': '130412'},
#      {'state': 'ND', 'state_draw_sales': '59832', 'state_pp_sales': '16340'},
#      {'state': 'NE', 'state_draw_sales': '224860', 'state_pp_sales': '18559'},
#      {'state': 'NH', 'state_draw_sales': '201838', 'state_pp_sales': '16472'},
#      {'state': 'NJ', 'state_draw_sales': '1048272', 'state_pp_sales': '67105'},
#      {'state': 'NM', 'state_draw_sales': '167840', 'state_pp_sales': '23985'},
#      {'state': 'NY', 'state_draw_sales': '1941194', 'state_pp_sales': '90309'},
#      {'state': 'OH', 'state_draw_sales': '690500', 'state_pp_sales': '82087'},
#      {'state': 'OK', 'state_draw_sales': '259198', 'state_pp_sales': '63900'},
#      {'state': 'OR', 'state_draw_sales': '338132', 'state_pp_sales': '26762'},
#      {'state': 'PA',
#       'state_draw_sales': '1243298',
#       'state_pp_sales': '162400'},
#      {'state': 'PR', 'state_draw_sales': '142', 'state_pp_sales': '47'},
#      {'state': 'RI', 'state_draw_sales': '173656', 'state_pp_sales': '21617'},
#      {'state': 'SC', 'state_draw_sales': '492306', 'state_pp_sales': '114248'},
#      {'state': 'SD', 'state_draw_sales': '80362', 'state_pp_sales': '12031'},
#      {'state': 'TN', 'state_draw_sales': '633892', 'state_pp_sales': '107353'},
#      {'state': 'TX',
#       'state_draw_sales': '1655914',
#       'state_pp_sales': '266347'},
#      {'state': 'VA', 'state_draw_sales': '682500', 'state_pp_sales': '71595'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '53448', 'state_pp_sales': '12661'},
#      {'state': 'WA', 'state_draw_sales': '329066', 'state_pp_sales': '25090'},
#      {'state': 'WI', 'state_draw_sales': '501658', 'state_pp_sales': '45690'},
#      {'state': 'WV', 'state_draw_sales': '223962', 'state_pp_sales': '20129'},
#      {'state': 'WY', 'state_draw_sales': '55902', 'state_pp_sales': '11681'}],
#     'total_sold': '12867809'},
#    {'date': '11/01/17',
#     'draw_sales': '22186600',
#     'jackpot': '52',
#     'pp_sales': '2255609',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '142078',
#       'state_pp_sales': '35348'},
#      {'state': 'AZ', 'state_draw_sales': '544798', 'state_pp_sales': '44624'},
#      {'state': 'CA', 'state_draw_sales': '2161464', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '366466', 'state_pp_sales': '88624'},
#      {'state': 'CT', 'state_draw_sales': '375338', 'state_pp_sales': '69471'},
#      {'state': 'DC', 'state_draw_sales': '61256', 'state_pp_sales': '5826'},
#      {'state': 'DE', 'state_draw_sales': '116452', 'state_pp_sales': '9726'},
#      {'state': 'FL',
#       'state_draw_sales': '2112452',
#       'state_pp_sales': '257998'},
#      {'state': 'GA', 'state_draw_sales': '680180', 'state_pp_sales': '42565'},
#      {'state': 'IA', 'state_draw_sales': '279422', 'state_pp_sales': '43911'},
#      {'state': 'ID', 'state_draw_sales': '173096', 'state_pp_sales': '20255'},
#      {'state': 'IL', 'state_draw_sales': '663564', 'state_pp_sales': '59619'},
#      {'state': 'IN', 'state_draw_sales': '466224', 'state_pp_sales': '47953'},
#      {'state': 'KS', 'state_draw_sales': '202002', 'state_pp_sales': '13093'},
#      {'state': 'KY', 'state_draw_sales': '399916', 'state_pp_sales': '30218'},
#      {'state': 'LA', 'state_draw_sales': '471326', 'state_pp_sales': '64257'},
#      {'state': 'MA', 'state_draw_sales': '516084', 'state_pp_sales': '34211'},
#      {'state': 'MD', 'state_draw_sales': '492188', 'state_pp_sales': '36077'},
#      {'state': 'ME', 'state_draw_sales': '101400', 'state_pp_sales': '26123'},
#      {'state': 'MI', 'state_draw_sales': '651596', 'state_pp_sales': '40721'},
#      {'state': 'MN', 'state_draw_sales': '352290', 'state_pp_sales': '17198'},
#      {'state': 'MO', 'state_draw_sales': '493766', 'state_pp_sales': '22842'},
#      {'state': 'MT', 'state_draw_sales': '70660', 'state_pp_sales': '13829'},
#      {'state': 'NC', 'state_draw_sales': '747294', 'state_pp_sales': '111355'},
#      {'state': 'ND', 'state_draw_sales': '57528', 'state_pp_sales': '15827'},
#      {'state': 'NE', 'state_draw_sales': '202836', 'state_pp_sales': '17011'},
#      {'state': 'NH', 'state_draw_sales': '166820', 'state_pp_sales': '13959'},
#      {'state': 'NJ', 'state_draw_sales': '932978', 'state_pp_sales': '61121'},
#      {'state': 'NM', 'state_draw_sales': '146334', 'state_pp_sales': '20917'},
#      {'state': 'NY', 'state_draw_sales': '1661490', 'state_pp_sales': '81698'},
#      {'state': 'OH', 'state_draw_sales': '596786', 'state_pp_sales': '70933'},
#      {'state': 'OK', 'state_draw_sales': '226438', 'state_pp_sales': '55983'},
#      {'state': 'OR', 'state_draw_sales': '271368', 'state_pp_sales': '24143'},
#      {'state': 'PA',
#       'state_draw_sales': '1052844',
#       'state_pp_sales': '140415'},
#      {'state': 'PR', 'state_draw_sales': '164', 'state_pp_sales': '50'},
#      {'state': 'RI', 'state_draw_sales': '142304', 'state_pp_sales': '18173'},
#      {'state': 'SC', 'state_draw_sales': '415242', 'state_pp_sales': '96345'},
#      {'state': 'SD', 'state_draw_sales': '72014', 'state_pp_sales': '10549'},
#      {'state': 'TN', 'state_draw_sales': '531794', 'state_pp_sales': '90002'},
#      {'state': 'TX',
#       'state_draw_sales': '1412280',
#       'state_pp_sales': '232247'},
#      {'state': 'VA', 'state_draw_sales': '602488', 'state_pp_sales': '65051'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '44148', 'state_pp_sales': '10449'},
#      {'state': 'WA', 'state_draw_sales': '313388', 'state_pp_sales': '24234'},
#      {'state': 'WI', 'state_draw_sales': '447378', 'state_pp_sales': '41575'},
#      {'state': 'WV', 'state_draw_sales': '193912', 'state_pp_sales': '17472'},
#      {'state': 'WY', 'state_draw_sales': '54754', 'state_pp_sales': '11611'}],
#     'total_sold': '11093300'},
#    {'date': '10/28/17',
#     'draw_sales': '24373782',
#     'jackpot': '40',
#     'pp_sales': '2465683',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '155548',
#       'state_pp_sales': '39238'},
#      {'state': 'AZ', 'state_draw_sales': '596602', 'state_pp_sales': '48558'},
#      {'state': 'CA', 'state_draw_sales': '2272362', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '376476', 'state_pp_sales': '93306'},
#      {'state': 'CT', 'state_draw_sales': '430762', 'state_pp_sales': '79490'},
#      {'state': 'DC', 'state_draw_sales': '65246', 'state_pp_sales': '6194'},
#      {'state': 'DE', 'state_draw_sales': '130362', 'state_pp_sales': '19767'},
#      {'state': 'FL',
#       'state_draw_sales': '2386168',
#       'state_pp_sales': '286523'},
#      {'state': 'GA', 'state_draw_sales': '757626', 'state_pp_sales': '44435'},
#      {'state': 'IA', 'state_draw_sales': '288576', 'state_pp_sales': '45130'},
#      {'state': 'ID', 'state_draw_sales': '179656', 'state_pp_sales': '21211'},
#      {'state': 'IL', 'state_draw_sales': '717890', 'state_pp_sales': '62869'},
#      {'state': 'IN', 'state_draw_sales': '555980', 'state_pp_sales': '55427'},
#      {'state': 'KS', 'state_draw_sales': '211956', 'state_pp_sales': '13327'},
#      {'state': 'KY', 'state_draw_sales': '448844', 'state_pp_sales': '33130'},
#      {'state': 'LA', 'state_draw_sales': '495106', 'state_pp_sales': '66764'},
#      {'state': 'MA', 'state_draw_sales': '592222', 'state_pp_sales': '37832'},
#      {'state': 'MD', 'state_draw_sales': '563820', 'state_pp_sales': '39173'},
#      {'state': 'ME', 'state_draw_sales': '123622', 'state_pp_sales': '31783'},
#      {'state': 'MI', 'state_draw_sales': '727054', 'state_pp_sales': '43281'},
#      {'state': 'MN', 'state_draw_sales': '356124', 'state_pp_sales': '16745'},
#      {'state': 'MO', 'state_draw_sales': '516864', 'state_pp_sales': '24300'},
#      {'state': 'MT', 'state_draw_sales': '74618', 'state_pp_sales': '14340'},
#      {'state': 'NC', 'state_draw_sales': '850186', 'state_pp_sales': '125815'},
#      {'state': 'ND', 'state_draw_sales': '58044', 'state_pp_sales': '16074'},
#      {'state': 'NE', 'state_draw_sales': '216714', 'state_pp_sales': '18101'},
#      {'state': 'NH', 'state_draw_sales': '201088', 'state_pp_sales': '16006'},
#      {'state': 'NJ', 'state_draw_sales': '1028738', 'state_pp_sales': '66069'},
#      {'state': 'NM', 'state_draw_sales': '150696', 'state_pp_sales': '21668'},
#      {'state': 'NY', 'state_draw_sales': '1878536', 'state_pp_sales': '88678'},
#      {'state': 'OH', 'state_draw_sales': '667244', 'state_pp_sales': '79178'},
#      {'state': 'OK', 'state_draw_sales': '232198', 'state_pp_sales': '57098'},
#      {'state': 'OR', 'state_draw_sales': '258398', 'state_pp_sales': '26946'},
#      {'state': 'PA',
#       'state_draw_sales': '1209332',
#       'state_pp_sales': '158386'},
#      {'state': 'PR', 'state_draw_sales': '174', 'state_pp_sales': '54'},
#      {'state': 'RI', 'state_draw_sales': '172724', 'state_pp_sales': '21076'},
#      {'state': 'SC', 'state_draw_sales': '48622', 'state_pp_sales': '112881'},
#      {'state': 'SD', 'state_draw_sales': '71320', 'state_pp_sales': '10570'},
#      {'state': 'TN', 'state_draw_sales': '585220', 'state_pp_sales': '98740'},
#      {'state': 'TX',
#       'state_draw_sales': '1596372',
#       'state_pp_sales': '259796'},
#      {'state': 'VA', 'state_draw_sales': '593206', 'state_pp_sales': '63991'},
#      {'state': 'VI', 'state_draw_sales': '0', 'state_pp_sales': '0'},
#      {'state': 'VT', 'state_draw_sales': '52168', 'state_pp_sales': '12665'},
#      {'state': 'WA', 'state_draw_sales': '294578', 'state_pp_sales': '23234'},
#      {'state': 'WI', 'state_draw_sales': '492730', 'state_pp_sales': '45059'},
#      {'state': 'WV', 'state_draw_sales': '203474', 'state_pp_sales': '18084'},
#      {'state': 'WY', 'state_draw_sales': '55536', 'state_pp_sales': '11691'}],
#     'total_sold': '12186891'},
#    {'date': '10/25/17',
#     'draw_sales': '34858690',
#     'jackpot': '191',
#     'pp_sales': '3045883',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '196032',
#       'state_pp_sales': '45838'},
#      {'state': 'AZ', 'state_draw_sales': '778770', 'state_pp_sales': '57904'},
#      {'state': 'CA', 'state_draw_sales': '4046960', 'state_pp_sales': 'NA'},
#      {'state': 'CO', 'state_draw_sales': '567266', 'state_pp_sales': '125287'},
#      {'state': 'CT', 'state_draw_sales': '575554', 'state_pp_sales': '95095'},
#      {'state': 'DC', 'state_draw_sales': '85122', 'state_pp_sales': '7472'},
#      {'state': 'DE', 'state_draw_sales': '167636', 'state_pp_sales': '12414'},
#      {'state': 'FL',
#       'state_draw_sales': '2940196',
#       'state_pp_sales': '332384'},
#      {'state': 'GA', 'state_draw_sales': '1015206', 'state_pp_sales': '56295'},
#      {'state': 'IA', 'state_draw_sales': '375738', 'state_pp_sales': '53354'},
#      {'state': 'ID', 'state_draw_sales': '229758', 'state_pp_sales': '25447'},
#      {'state': 'IL', 'state_draw_sales': '1101030', 'state_pp_sales': '87185'},
#      {'state': 'IN', 'state_draw_sales': '691940', 'state_pp_sales': '62932'},
#      {'state': 'KS', 'state_draw_sales': '282366', 'state_pp_sales': '16547'},
#      {'state': 'KY', 'state_draw_sales': '555830', 'state_pp_sales': '38644'},
#      {'state': 'LA', 'state_draw_sales': '632300', 'state_pp_sales': '78240'},
#      {'state': 'MA', 'state_draw_sales': '880502', 'state_pp_sales': '48093'},
#      {'state': 'MD', 'state_draw_sales': '728344', 'state_pp_sales': '46799'},
# ...
#      {'state': 'NJ', 'state_draw_sales': '969346', 'state_pp_sales': '142616'},
#      {'state': 'NM', 'state_draw_sales': '231613', 'state_pp_sales': '37498'},
#      {'state': 'NY',
#       'state_draw_sales': '1458878',
#       'state_pp_sales': '108818'},
#      {'state': 'OK', 'state_draw_sales': '387031', 'state_pp_sales': '160648'},
#      {'state': 'OR', 'state_draw_sales': '274233', 'state_pp_sales': '59282'},
#      {'state': 'PA',
#       'state_draw_sales': '1649196',
#       'state_pp_sales': '350540'},
#      {'state': 'RI', 'state_draw_sales': '259953', 'state_pp_sales': '38321'},
#      {'state': 'SC', 'state_draw_sales': '640387', 'state_pp_sales': '257861'},
#      {'state': 'SD', 'state_draw_sales': '101062', 'state_pp_sales': '15785'},
#      {'state': 'TN', 'state_draw_sales': '794036', 'state_pp_sales': '198420'},
#      {'state': 'TX', 'state_draw_sales': '627873', 'state_pp_sales': '169340'},
#      {'state': 'VA', 'state_draw_sales': '506951', 'state_pp_sales': '125922'},
#      {'state': 'VI', 'state_draw_sales': '23489', 'state_pp_sales': '15263'},
#      {'state': 'VT', 'state_draw_sales': '62371', 'state_pp_sales': '21609'},
#      {'state': 'WA', 'state_draw_sales': '287411', 'state_pp_sales': '28434'},
#      {'state': 'WI', 'state_draw_sales': '552902', 'state_pp_sales': '62035'}],
#     'total_sold': 'NA'},
#    {'date': '3/17/10',
#     'draw_sales': '22336363',
#     'jackpot': '20',
#     'pp_sales': '4237993',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '305905',
#       'state_pp_sales': '123458'},
#      {'state': 'AZ', 'state_draw_sales': '824083', 'state_pp_sales': '76118'},
#      {'state': 'CO', 'state_draw_sales': '486257', 'state_pp_sales': '205246'},
#      {'state': 'CT', 'state_draw_sales': '416367', 'state_pp_sales': '104740'},
#      {'state': 'DC', 'state_draw_sales': '130455', 'state_pp_sales': '19323'},
#      {'state': 'DE', 'state_draw_sales': '155173', 'state_pp_sales': '17656'},
#      {'state': 'FL',
#       'state_draw_sales': '2485313',
#       'state_pp_sales': '519325'},
#      {'state': 'GA', 'state_draw_sales': '626274', 'state_pp_sales': '74213'},
#      {'state': 'IA', 'state_draw_sales': '351613', 'state_pp_sales': '71757'},
#      {'state': 'ID', 'state_draw_sales': '247064', 'state_pp_sales': '34674'},
#      {'state': 'IL', 'state_draw_sales': '681253', 'state_pp_sales': '147914'},
#      {'state': 'IN', 'state_draw_sales': '676309', 'state_pp_sales': '135376'},
#      {'state': 'KS', 'state_draw_sales': '270361', 'state_pp_sales': '21920'},
#      {'state': 'KY', 'state_draw_sales': '669474', 'state_pp_sales': '60673'},
#      {'state': 'LA', 'state_draw_sales': '629859', 'state_pp_sales': '104086'},
#      {'state': 'MA', 'state_draw_sales': '473132', 'state_pp_sales': '53466'},
#      {'state': 'MD', 'state_draw_sales': '476209', 'state_pp_sales': '41858'},
#      {'state': 'ME', 'state_draw_sales': '132484', 'state_pp_sales': '51444'},
#      {'state': 'MI', 'state_draw_sales': '685558', 'state_pp_sales': '139745'},
#      {'state': 'MN', 'state_draw_sales': '493774', 'state_pp_sales': '34247'},
#      {'state': 'MO', 'state_draw_sales': '709554', 'state_pp_sales': '55143'},
#      {'state': 'MT', 'state_draw_sales': '112589', 'state_pp_sales': '27618'},
#      {'state': 'NC',
#       'state_draw_sales': '1056641',
#       'state_pp_sales': '331537'},
#      {'state': 'ND', 'state_draw_sales': '62661', 'state_pp_sales': '26490'},
#      {'state': 'NE', 'state_draw_sales': '274055', 'state_pp_sales': '35380'},
#      {'state': 'NH', 'state_draw_sales': '220913', 'state_pp_sales': '23537'},
#      {'state': 'NJ', 'state_draw_sales': '967884', 'state_pp_sales': '139030'},
#      {'state': 'NM', 'state_draw_sales': '220366', 'state_pp_sales': '35540'},
#      {'state': 'NY',
#       'state_draw_sales': '1440960',
#       'state_pp_sales': '108067'},
#      {'state': 'OK', 'state_draw_sales': '373353', 'state_pp_sales': '151350'},
#      {'state': 'OR', 'state_draw_sales': '268053', 'state_pp_sales': '57124'},
#      {'state': 'PA',
#       'state_draw_sales': '1477653',
#       'state_pp_sales': '315431'},
#      {'state': 'RI', 'state_draw_sales': '232422', 'state_pp_sales': '34880'},
#      {'state': 'SC', 'state_draw_sales': '580270', 'state_pp_sales': '232320'},
#      {'state': 'SD', 'state_draw_sales': '96243', 'state_pp_sales': '15398'},
#      {'state': 'TN', 'state_draw_sales': '719383', 'state_pp_sales': '179959'},
#      {'state': 'TX', 'state_draw_sales': '605994', 'state_pp_sales': '161125'},
#      {'state': 'VA', 'state_draw_sales': '486845', 'state_pp_sales': '120090'},
#      {'state': 'VI', 'state_draw_sales': '22727', 'state_pp_sales': '14474'},
#      {'state': 'VT', 'state_draw_sales': '57024', 'state_pp_sales': '19385'},
#      {'state': 'WA', 'state_draw_sales': '290447', 'state_pp_sales': '29532'},
#      {'state': 'WI', 'state_draw_sales': '532508', 'state_pp_sales': '59934'}],
#     'total_sold': 'NA'},
#    {'date': '3/13/10',
#     'draw_sales': '57239387',
#     'jackpot': '211',
#     'pp_sales': '8335800',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '548364',
#       'state_pp_sales': '197899'},
#      {'state': 'AZ',
#       'state_draw_sales': '2228582',
#       'state_pp_sales': '145911'},
#      {'state': 'CO',
#       'state_draw_sales': '1405438',
#       'state_pp_sales': '474604'},
#      {'state': 'CT',
#       'state_draw_sales': '1055210',
#       'state_pp_sales': '202010'},
#      {'state': 'DC', 'state_draw_sales': '258526', 'state_pp_sales': '31913'},
#      {'state': 'DE', 'state_draw_sales': '448529', 'state_pp_sales': '36206'},
#      {'state': 'FL',
#       'state_draw_sales': '7548706',
#       'state_pp_sales': '1250659'},
#      {'state': 'GA',
#       'state_draw_sales': '1559395',
#       'state_pp_sales': '138162'},
#      {'state': 'IA', 'state_draw_sales': '811209', 'state_pp_sales': '136392'},
#      {'state': 'ID', 'state_draw_sales': '485111', 'state_pp_sales': '59597'},
#      {'state': 'IL',
#       'state_draw_sales': '1884823',
#       'state_pp_sales': '307492'},
#      {'state': 'IN',
#       'state_draw_sales': '1663313',
#       'state_pp_sales': '260136'},
#      {'state': 'KS', 'state_draw_sales': '649954', 'state_pp_sales': '41023'},
#      {'state': 'KY',
#       'state_draw_sales': '1384253',
#       'state_pp_sales': '100536'},
#      {'state': 'LA',
#       'state_draw_sales': '1517713',
#       'state_pp_sales': '180265'},
#      {'state': 'MA',
#       'state_draw_sales': '1474089',
#       'state_pp_sales': '107624'},
#      {'state': 'MD', 'state_draw_sales': '1001173', 'state_pp_sales': '68083'},
#      {'state': 'ME', 'state_draw_sales': '243964', 'state_pp_sales': '83003'},
#      {'state': 'MI',
#       'state_draw_sales': '1574206',
#       'state_pp_sales': '248721'},
#      {'state': 'MN', 'state_draw_sales': '1430456', 'state_pp_sales': '65417'},
#      {'state': 'MO', 'state_draw_sales': '1545450', 'state_pp_sales': '91730'},
#      {'state': 'MT', 'state_draw_sales': '201294', 'state_pp_sales': '41652'},
#      {'state': 'NC',
#       'state_draw_sales': '2235376',
#       'state_pp_sales': '591970'},
#      {'state': 'ND', 'state_draw_sales': '127671', 'state_pp_sales': '46958'},
#      {'state': 'NE', 'state_draw_sales': '631118', 'state_pp_sales': '59099'},
#      {'state': 'NH', 'state_draw_sales': '611757', 'state_pp_sales': '46828'},
#      {'state': 'NJ',
#       'state_draw_sales': '2406259',
#       'state_pp_sales': '242178'},
#      {'state': 'NM', 'state_draw_sales': '580016', 'state_pp_sales': '72822'},
#      {'state': 'NY',
#       'state_draw_sales': '4309454',
#       'state_pp_sales': '215281'},
#      {'state': 'OK', 'state_draw_sales': '880703', 'state_pp_sales': '315264'},
#      {'state': 'OR', 'state_draw_sales': '882108', 'state_pp_sales': '131592'},
#      {'state': 'PA',
#       'state_draw_sales': '4925884',
#       'state_pp_sales': '754623'},
#      {'state': 'RI', 'state_draw_sales': '569342', 'state_pp_sales': '63892'},
#      {'state': 'SC',
#       'state_draw_sales': '1263367',
#       'state_pp_sales': '440619'},
#      {'state': 'SD', 'state_draw_sales': '228723', 'state_pp_sales': '27480'},
#      {'state': 'TN',
#       'state_draw_sales': '1649755',
#       'state_pp_sales': '343306'},
#      {'state': 'TX',
#       'state_draw_sales': '1272392',
#       'state_pp_sales': '262519'},
#      {'state': 'VA', 'state_draw_sales': '993039', 'state_pp_sales': '191458'},
#      {'state': 'VI', 'state_draw_sales': '40755', 'state_pp_sales': '24590'},
#      {'state': 'VT', 'state_draw_sales': '109425', 'state_pp_sales': '33232'},
#      {'state': 'WA', 'state_draw_sales': '603020', 'state_pp_sales': '49905'},
#      {'state': 'WI',
#       'state_draw_sales': '1276799',
#       'state_pp_sales': '104000'}],
#     'total_sold': 'NA'},
#    {'date': '3/10/10',
#     'draw_sales': '41968422',
#     'jackpot': '172',
#     'pp_sales': '6470707',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '429138',
#       'state_pp_sales': '163213'},
#      {'state': 'AZ',
#       'state_draw_sales': '1538511',
#       'state_pp_sales': '115149'},
#      {'state': 'CO', 'state_draw_sales': '993104', 'state_pp_sales': '345704'},
#      {'state': 'CT', 'state_draw_sales': '796955', 'state_pp_sales': '161465'},
#      {'state': 'DC', 'state_draw_sales': '221071', 'state_pp_sales': '27985'},
#      {'state': 'DE', 'state_draw_sales': '326646', 'state_pp_sales': '27875'},
#      {'state': 'FL',
#       'state_draw_sales': '5111364',
#       'state_pp_sales': '918544'},
#      {'state': 'GA',
#       'state_draw_sales': '1100673',
#       'state_pp_sales': '112077'},
#      {'state': 'IA', 'state_draw_sales': '607325', 'state_pp_sales': '106387'},
#      {'state': 'ID', 'state_draw_sales': '357425', 'state_pp_sales': '45751'},
#      {'state': 'IL',
#       'state_draw_sales': '1474843',
#       'state_pp_sales': '257129'},
#      {'state': 'IN',
#       'state_draw_sales': '1060497',
#       'state_pp_sales': '178446'},
#      {'state': 'KS', 'state_draw_sales': '455257', 'state_pp_sales': '30774'},
#      {'state': 'KY', 'state_draw_sales': '1009562', 'state_pp_sales': '79665'},
#      {'state': 'LA',
#       'state_draw_sales': '1131893',
#       'state_pp_sales': '149582'},
#      {'state': 'MA', 'state_draw_sales': '1097935', 'state_pp_sales': '88620'},
#      {'state': 'MD', 'state_draw_sales': '753912', 'state_pp_sales': '56726'},
#      {'state': 'ME', 'state_draw_sales': '179752', 'state_pp_sales': '63327'},
#      {'state': 'MI',
#       'state_draw_sales': '1231175',
#       'state_pp_sales': '211392'},
#      {'state': 'MN', 'state_draw_sales': '1041977', 'state_pp_sales': '52008'},
#      {'state': 'MO', 'state_draw_sales': '1145457', 'state_pp_sales': '73082'},
#      {'state': 'MT', 'state_draw_sales': '155283', 'state_pp_sales': '33995'},
#      {'state': 'NC',
#       'state_draw_sales': '1620511',
#       'state_pp_sales': '453231'},
#      {'state': 'ND', 'state_draw_sales': '93715', 'state_pp_sales': '36168'},
#      {'state': 'NE', 'state_draw_sales': '486052', 'state_pp_sales': '48696'},
#      {'state': 'NH', 'state_draw_sales': '395445', 'state_pp_sales': '33806'},
#      {'state': 'NJ',
#       'state_draw_sales': '2070834',
#       'state_pp_sales': '225392'},
#      {'state': 'NM', 'state_draw_sales': '412425', 'state_pp_sales': '55055'},
#      {'state': 'NY',
#       'state_draw_sales': '3428821',
#       'state_pp_sales': '184224'},
#      {'state': 'OK', 'state_draw_sales': '644815', 'state_pp_sales': '236502'},
#      {'state': 'OR', 'state_draw_sales': '638183', 'state_pp_sales': '100442'},
#      {'state': 'PA',
#       'state_draw_sales': '3381724',
#       'state_pp_sales': '545873'},
#      {'state': 'RI', 'state_draw_sales': '415961', 'state_pp_sales': '51231'},
#      {'state': 'SC', 'state_draw_sales': '905007', 'state_pp_sales': '325566'},
#      {'state': 'SD', 'state_draw_sales': '178690', 'state_pp_sales': '21985'},
#      {'state': 'TN',
#       'state_draw_sales': '1176339',
#       'state_pp_sales': '254886'},
#      {'state': 'TX',
#       'state_draw_sales': '1014050',
#       'state_pp_sales': '224817'},
#      {'state': 'VA', 'state_draw_sales': '805432', 'state_pp_sales': '164704'},
#      {'state': 'VI', 'state_draw_sales': '30820', 'state_pp_sales': '18756'},
#      {'state': 'VT', 'state_draw_sales': '77972', 'state_pp_sales': '24523'},
#      {'state': 'WA', 'state_draw_sales': '502779', 'state_pp_sales': '42562'},
#      {'state': 'WI', 'state_draw_sales': '947652', 'state_pp_sales': '84810'}],
#     'total_sold': 'NA'},
#    {'date': '3/6/10',
#     'draw_sales': '37513118',
#     'jackpot': '144',
#     'pp_sales': '6303025',
#     'states_data': [{'state': 'AR',
#       'state_draw_sales': '420410',
#       'state_pp_sales': '167502'},
#      {'state': 'AZ',
#       'state_draw_sales': '1422115',
#       'state_pp_sales': '112359'},
#      {'state': 'CO', 'state_draw_sales': '920755', 'state_pp_sales': '338886'},
#      {'state': 'CT', 'state_draw_sales': '701985', 'state_pp_sales': '152635'},
#      {'state': 'DC', 'state_draw_sales': '187044', 'state_pp_sales': '26262'},
#      {'state': 'DE', 'state_draw_sales': '287063', 'state_pp_sales': '27425'},
#      {'state': 'FL',
#       'state_draw_sales': '4729430',
#       'state_pp_sales': '886755'},
#      {'state': 'GA',
#       'state_draw_sales': '1049156',
#       'state_pp_sales': '109045'},
#      {'state': 'IA', 'state_draw_sales': '555783', 'state_pp_sales': '103152'},
#      {'state': 'ID', 'state_draw_sales': '332707', 'state_pp_sales': '43467'},
#      {'state': 'IL',
#       'state_draw_sales': '1219660',
#       'state_pp_sales': '235365'},
#      {'state': 'IN',
#       'state_draw_sales': '1063271',
#       'state_pp_sales': '189490'},
#      {'state': 'KS', 'state_draw_sales': '443037', 'state_pp_sales': '31169'},
#      {'state': 'KY', 'state_draw_sales': '970517', 'state_pp_sales': '80946'},
#      {'state': 'LA',
#       'state_draw_sales': '1074301',
#       'state_pp_sales': '150072'},
#      {'state': 'MA', 'state_draw_sales': '914353', 'state_pp_sales': '80292'},
#      {'state': 'MD', 'state_draw_sales': '677594', 'state_pp_sales': '54823'},
#      {'state': 'ME', 'state_draw_sales': '188451', 'state_pp_sales': '69451'},
#      {'state': 'MI',
#       'state_draw_sales': '1096883',
#       'state_pp_sales': '203231'},
#      {'state': 'MN', 'state_draw_sales': '936736', 'state_pp_sales': '50241'},
#      {'state': 'MO', 'state_draw_sales': '1098912', 'state_pp_sales': '74197'},
#      {'state': 'MT', 'state_draw_sales': '146867', 'state_pp_sales': '33591'},
#      {'state': 'NC',
#       'state_draw_sales': '1584178',
#       'state_pp_sales': '459696'},
#      {'state': 'ND', 'state_draw_sales': '85179', 'state_pp_sales': '33832'},
#      {'state': 'NE', 'state_draw_sales': '441431', 'state_pp_sales': '46663'},
#      {'state': 'NH', 'state_draw_sales': '361010', 'state_pp_sales': '32769'},
#      {'state': 'NJ',
#       'state_draw_sales': '1565677',
#       'state_pp_sales': '203024'},
#      {'state': 'NM', 'state_draw_sales': '383719', 'state_pp_sales': '54719'},
#      {'state': 'NY',
#       'state_draw_sales': '2517663',
#       'state_pp_sales': '155445'},
#      {'state': 'OK', 'state_draw_sales': '604024', 'state_pp_sales': '231666'},
#      {'state': 'OR', 'state_draw_sales': '557447', 'state_pp_sales': '94738'},
#      {'state': 'PA',
#       'state_draw_sales': '2900573',
#       'state_pp_sales': '513460'},
#      {'state': 'RI', 'state_draw_sales': '401702', 'state_pp_sales': '50315'},
#      {'state': 'SC', 'state_draw_sales': '908233', 'state_pp_sales': '342718'},
#      {'state': 'SD', 'state_draw_sales': '158811', 'state_pp_sales': '21011'},
#      {'state': 'TN',
#       'state_draw_sales': '1134766',
#       'state_pp_sales': '258415'},
#      {'state': 'TX', 'state_draw_sales': '903322', 'state_pp_sales': '216572'},
#      {'state': 'VA', 'state_draw_sales': '722125', 'state_pp_sales': '166211'},
#      {'state': 'VI', 'state_draw_sales': '29840', 'state_pp_sales': '18816'},
#      {'state': 'VT', 'state_draw_sales': '78778', 'state_pp_sales': '25085'},
#      {'state': 'WA', 'state_draw_sales': '414727', 'state_pp_sales': '38536'},
#      {'state': 'WI', 'state_draw_sales': '845169', 'state_pp_sales': '81542'}],
#     'total_sold': 'NA'}],
#   'link': 'PBSalesbystate12010.htm'}]

# %%
sales = []

for x in range(len(total_data)):
    for day in total_data[x]['data']:
        date = day['date']
        draw_sales = day['draw_sales']
        jackpot = day['jackpot']
        pp_sales = day['pp_sales']
        for each in day['states_data']:
            day_dict = {}
            state = each['state']
            state_draw_sales = each['state_draw_sales']
            state_pp_sales = each['state_pp_sales']
            day_dict = {
                "date": date,
                "draw_sales": draw_sales,
                "jackpot": jackpot,
                "pp_sales": pp_sales,
                "state": state,
                "state_draw_sales": state_draw_sales,
                "state_pp_sales": state_pp_sales
            }
            sales.append(day_dict)

# %%
len(sales)
# Out:
# 37188

# %%
sales_df = pd.DataFrame(sales)

# %%
sales_df
# Out:
#            date draw_sales jackpot pp_sales state state_draw_sales  \
# 0      12/06/17         NA     193       NA    AR               NA
# 1      12/06/17         NA     193       NA    AZ               NA
# 2      12/06/17         NA     193       NA    CA               NA
# 3      12/06/17         NA     193       NA    CO               NA
# 4      12/06/17         NA     193       NA    CT               NA
# 5      12/06/17         NA     193       NA    DC               NA
# 6      12/06/17         NA     193       NA    DE               NA
# 7      12/06/17         NA     193       NA    FL               NA
# 8      12/06/17         NA     193       NA    GA               NA
# 9      12/06/17         NA     193       NA    IA               NA
# 10     12/06/17         NA     193       NA    ID               NA
# 11     12/06/17         NA     193       NA    IL               NA
# 12     12/06/17         NA     193       NA    IN               NA
# 13     12/06/17         NA     193       NA    KS               NA
# 14     12/06/17         NA     193       NA    KY               NA
# 15     12/06/17         NA     193       NA    LA               NA
# 16     12/06/17         NA     193       NA    MA               NA
# 17     12/06/17         NA     193       NA    MD               NA
# 18     12/06/17         NA     193       NA    ME               NA
# 19     12/06/17         NA     193       NA    MI               NA
# 20     12/06/17         NA     193       NA    MN               NA
# 21     12/06/17         NA     193       NA    MO               NA
# 22     12/06/17         NA     193       NA    MT               NA
# 23     12/06/17         NA     193       NA    NC               NA
# 24     12/06/17         NA     193       NA    ND               NA
# 25     12/06/17         NA     193       NA    NE               NA
# 26     12/06/17         NA     193       NA    NH               NA
# 27     12/06/17         NA     193       NA    NJ               NA
# 28     12/06/17         NA     193       NA    NM               NA
# 29     12/06/17         NA     193       NA    NY               NA
# ...         ...        ...     ...      ...   ...              ...
# 37158    3/6/10   37513118     144  6303025    KS           443037
# 37159    3/6/10   37513118     144  6303025    KY           970517
# 37160    3/6/10   37513118     144  6303025    LA          1074301
# 37161    3/6/10   37513118     144  6303025    MA           914353
# 37162    3/6/10   37513118     144  6303025    MD           677594
# 37163    3/6/10   37513118     144  6303025    ME           188451
# 37164    3/6/10   37513118     144  6303025    MI          1096883
# 37165    3/6/10   37513118     144  6303025    MN           936736
# 37166    3/6/10   37513118     144  6303025    MO          1098912
# 37167    3/6/10   37513118     144  6303025    MT           146867
# 37168    3/6/10   37513118     144  6303025    NC          1584178
# 37169    3/6/10   37513118     144  6303025    ND            85179
# 37170    3/6/10   37513118     144  6303025    NE           441431
# 37171    3/6/10   37513118     144  6303025    NH           361010
# 37172    3/6/10   37513118     144  6303025    NJ          1565677
# 37173    3/6/10   37513118     144  6303025    NM           383719
# 37174    3/6/10   37513118     144  6303025    NY          2517663
# 37175    3/6/10   37513118     144  6303025    OK           604024
# 37176    3/6/10   37513118     144  6303025    OR           557447
# 37177    3/6/10   37513118     144  6303025    PA          2900573
# 37178    3/6/10   37513118     144  6303025    RI           401702
# 37179    3/6/10   37513118     144  6303025    SC           908233
# 37180    3/6/10   37513118     144  6303025    SD           158811
# 37181    3/6/10   37513118     144  6303025    TN          1134766
# 37182    3/6/10   37513118     144  6303025    TX           903322
# 37183    3/6/10   37513118     144  6303025    VA           722125
# 37184    3/6/10   37513118     144  6303025    VI            29840
# 37185    3/6/10   37513118     144  6303025    VT            78778
# 37186    3/6/10   37513118     144  6303025    WA           414727
# 37187    3/6/10   37513118     144  6303025    WI           845169
#
#       state_pp_sales
# 0                 NA
# 1                 NA
# 2                 NA
# 3                 NA
# 4                 NA
# 5                 NA
# 6                 NA
# 7                 NA
# 8                 NA
# 9                 NA
# 10                NA
# 11                NA
# 12                NA
# 13                NA
# 14                NA
# 15                NA
# 16                NA
# 17                NA
# 18                NA
# 19                NA
# 20                NA
# 21                NA
# 22                NA
# 23                NA
# 24                NA
# 25                NA
# 26                NA
# 27                NA
# 28                NA
# 29                NA
# ...              ...
# 37158          31169
# 37159          80946
# 37160         150072
# 37161          80292
# 37162          54823
# 37163          69451
# 37164         203231
# 37165          50241
# 37166          74197
# 37167          33591
# 37168         459696
# 37169          33832
# 37170          46663
# 37171          32769
# 37172         203024
# 37173          54719
# 37174         155445
# 37175         231666
# 37176          94738
# 37177         513460
# 37178          50315
# 37179         342718
# 37180          21011
# 37181         258415
# 37182         216572
# 37183         166211
# 37184          18816
# 37185          25085
# 37186          38536
# 37187          81542
#
# [37188 rows x 7 columns]

# %%
sales_df.tail()
# Out:
#          date draw_sales jackpot pp_sales state state_draw_sales  \
# 37183  3/6/10   37513118     144  6303025    VA           722125
# 37184  3/6/10   37513118     144  6303025    VI            29840
# 37185  3/6/10   37513118     144  6303025    VT            78778
# 37186  3/6/10   37513118     144  6303025    WA           414727
# 37187  3/6/10   37513118     144  6303025    WI           845169
#
#       state_pp_sales
# 37183         166211
# 37184          18816
# 37185          25085
# 37186          38536
# 37187          81542

# %%
sales_df.to_csv("lotto_sales.csv", index = False)
