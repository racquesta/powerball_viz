# %%
from pymongo import MongoClient
from mLab import username, password

client = MongoClient("mongodb://%s:%s@ds133816.mlab.com:33816/heroku_sdvkxt9m" % (username, password))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-71-2a6abb35b45e> in <module>()
#       1 from pymongo import MongoClient
# ----> 2 from mLab import username, password
#       3
#       4 client = MongoClient("mongodb://%s:%s@ds133816.mlab.com:33816/heroku_sdvkxt9m" % (username, password))
#
# ModuleNotFoundError: No module named 'mLab'

# %%
db = client.heroku_sdvkxt9m

# %%
total_collection = db.total_collection

# %%
import pandas as pd

# %%
final_json = pd.read_json('../final.json')

# %%
final_json.head()
# Out:
#    1_PB PB  1_PB PP  2_PB PB  2_PB PP  3 PB  3 PP  3_PB PB  3_PB PP  4 PB  \
# 0      NaN      NaN      NaN      NaN   NaN   NaN      NaN      NaN   NaN
# 1      NaN      NaN      NaN      NaN   NaN   NaN      NaN      NaN   NaN
# 2      NaN      NaN      NaN      NaN   NaN   NaN      NaN      NaN   NaN
# 3      NaN      NaN      NaN      NaN   NaN   NaN      NaN      NaN   NaN
# 4      NaN      NaN      NaN      NaN   NaN   NaN      NaN      NaN   NaN
#
#    4 PP  ...   pp_winners  revenue  state_abbr  state_draw_sales  \
# 0   NaN  ...          NaN   257063          AR            207040
# 1   NaN  ...          NaN   850368          AZ            790702
# 2   NaN  ...          NaN  3292686          CA           3292686
# 3   NaN  ...          NaN   686928          CO            560076
# 4   NaN  ...          NaN    87125          DC             80140
#
#    state_pp_sales  states  ticket_sales  total_winners      unique_id  year
# ...

# %%
hist_data = final_json.to_dict(orient = 'records')

# %%
hist_data
# Out:
# [{'1_PB PB': nan,
#   '1_PB PP': nan,
#   '2_PB PB': nan,
#   '2_PB PP': nan,
#   '3 PB': nan,
#   '3 PP': nan,
#   '3_PB PB': nan,
#   '3_PB PP': nan,
#   '4 PB': nan,
#   '4 PP': nan,
#   '4_PB PB': nan,
#   '4_PB PP': nan,
#   '5 PB': nan,
#   '5 PP': nan,
#   '5_PB PB': nan,
#   'Household Income': nan,
#   'Median Age': nan,
#   'PB_Only PB': nan,
#   'PB_Only PP': nan,
#   'Per Capita Income': nan,
#   'Population': nan,
#   'Poverty Count': nan,
#   'Poverty Rate': nan,
#   'Unemployment Count': nan,
#   'Unemployment Rate': nan,
#   'date_format': '2017-12-02',
#   'draw_sales': 33842134,
#   'jackpot': 177.0,
#   'numbers': None,
#   'pb_winners': nan,
#   'powerball': nan,
#   'pp_sales': 3144938,
#   'pp_winners': nan,
#   'revenue': 257063,
#   'state_abbr': 'AR',
#   'state_draw_sales': 207040,
#   'state_pp_sales': 50023,
#   'states': None,
#   'ticket_sales': 103520.0,
#   'total_winners': nan,
#   'unique_id': '2017-12-02_AR',
#   'year': 2017},
#  {'1_PB PB': nan,
# ...

# %%
total_collection.insert_many(hist_data)

# %%
total_collection.count()
# Out:
# 36139

# %%
# example query
results = total_collection.find({'year': 2016}, {'jackpot':1, '_id':0} )

# %%
for x in results:
    print(x)
# Out:
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 70.0}
# {'jackpot': 60.0}
# {'jackpot': 60.0}
# {'jackpot': 60.0}
# ...

# %%
# group by example
pipe = [{'$group': {'_id': '$year', 'total': {'$avg': '$jackpot'}}}]
results = total_collection.aggregate(pipeline=pipe)
results

# %%
for x in results:
    print(x)
# Out:
# {'_id': 2010, 'total': 71.49023331524688}
# {'_id': 2011, 'total': 74.80440948371371}
# {'_id': 2012, 'total': 108.34134615384616}
# {'_id': 2013, 'total': 120.09160070360598}
# {'_id': 2017, 'total': 161.1314165186501}
# {'_id': 2016, 'total': 188.6809523809524}
# {'_id': 2015, 'total': 117.65767480347537}
# {'_id': 2014, 'total': 102.93931568754034}
